# %% [markdown]
# <a href="https://colab.research.google.com/github/kilos11/AJAY_R_Datasets_For_Work/blob/main/TorchVision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np

import torch
import torchvision.transforms as T
from torchvision.io import read_image


plt.rcParams["savefig.bbox"] = 'tight'
torch.manual_seed(1)


def show(imgs):
    fix, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    for i, img in enumerate(imgs):
        img = T.ToPILImage()(img.to('cpu'))
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# %%
pottery1 = read_image(str(Path('images') / 'pottery1.jpeg'))
pottery2 = read_image(str(Path('images') / 'pottery3.png'))
show([pottery1, pottery2])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-9ff530fe139a> in <cell line: 1>()
# ----> 1 pottery1 = read_image(str(Path('images') / 'pottery1.jpeg'))
#       2 pottery2 = read_image(str(Path('images') / 'pottery3.png'))
#       3 show([pottery1, pottery2])
#
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py in read_image(path, mode)
#     256     if not torch.jit.is_scripting() and not torch.jit.is_tracing():
#     257         _log_api_usage_once(read_image)
# --> 258     data = read_file(path)
#     259     return decode_image(data, mode)
#     260
#
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py in read_file(path)
#      50     if not torch.jit.is_scripting() and not torch.jit.is_tracing():
#      51         _log_api_usage_once(read_file)
# ---> 52     data = torch.ops.image.read_file(path)
#      53     return data
#      54
#
# /usr/local/lib/python3.10/dist-packages/torch/_ops.py in __call__(self, *args, **kwargs)
#     690         # We save the function ptr as the `op` attribute on
#     691         # OpOverloadPacket to access it here.
# --> 692         return self._op(*args, **kwargs or {})
#     693
#     694     # TODO: use this to make a __dir__
#
# RuntimeError: [Errno 2] No such file or directory: 'images/pottery1.jpeg'

# %%
def plot(imgs, with_orig=True, row_title=None, **imshow_kwargs):
    if not isinstance(imgs[0], list):
        # Make a 2d grid even if there's just 1 row
        imgs = [imgs]

    num_rows = len(imgs)
    num_cols = len(imgs[0]) + with_orig
    fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols, squeeze=False)
    for row_idx, row in enumerate(imgs):
        row = [orig_img] + row if with_orig else row
        for col_idx, img in enumerate(row):
            ax = axs[row_idx, col_idx]
            ax.imshow(np.asarray(img), **imshow_kwargs)
            ax.set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

    if with_orig:
        axs[0, 0].set(title='Original image')
        axs[0, 0].title.set_size(8)
    if row_title is not None:
        for row_idx in range(num_rows):
            axs[row_idx, 0].set(ylabel=row_title[row_idx])

    plt.tight_layout()

# %%
# Most transforms natively support tensors on top of PIL images
# image padding

from PIL import Image
plt.rcParams["savefig.bbox"] = 'tight'
orig_img = Image.open(Path('images') / 'pottery1.jpeg')

padded_imgs = [T.Pad(padding=padding)(orig_img) for padding in (3, 10, 30, 50)]
plot(padded_imgs)

# %%
# try some random crop

import torch.nn as nn

transforms = torch.nn.Sequential(
    T.RandomCrop(224),
    T.RandomHorizontalFlip(p=0.3),
)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
pottery1 = pottery1.to(device)
pottery2 = pottery2.to(device)

transformed_pottery1 = transforms(pottery1)
transformed_pottery2 = transforms(pottery2)
show([transformed_pottery1, transformed_pottery2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a67ed1a7fe57> in <cell line: 11>()
#       9
#      10 device = 'cuda' if torch.cuda.is_available() else 'cpu'
# ---> 11 pottery1 = pottery1.to(device)
#      12 pottery2 = pottery2.to(device)
#      13
#
# NameError: name 'pottery1' is not defined

# %%
# color jitter
jitter = T.ColorJitter(brightness=.5, hue=.3)
jitted_imgs = [jitter(orig_img) for _ in range(4)]
plot(jitted_imgs)

# %%
# random perspectives
perspective_transformer = T.RandomPerspective(distortion_scale=0.6, p=1.0)
perspective_imgs = [perspective_transformer(orig_img) for _ in range(4)]
plot(perspective_imgs)

# %%
# various center crop
center_crops = [T.CenterCrop(size=size)(orig_img) for size in (30, 50, 100, orig_img.size)]
plot(center_crops)
